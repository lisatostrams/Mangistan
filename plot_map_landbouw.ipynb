# %%
import osmnx as ox


import matplotlib.pyplot as plt

import networkx as nx

import pandas as pd

import numpy as np

import matplotlib.cm as cm

import csv


from shapely import geometry


query = {'state': 'Utrecht'}

# get the boundaries of the place
utrecht_boundary = ox.geocode_to_gdf(query)
utrecht_boundary.plot()

# or just get the street network within the place
# G = ox.graph_from_place(query, network_type='drive')
# fig, ax = ox.plot_graph(G, edge_linewidth=0)
# Out:
# <AxesSubplot:>

# %%
# nodes, edges = ox.graph_to_gdfs(G, nodes=True, edges=True)


# xmax = nodes.x.max()
# xmin = nodes.x.min()
# ymin = nodes.y.min()
# ymax = nodes.y.max()

xmin, ymin, xmax, ymax = utrecht_boundary.geometry[0].bounds

print(xmin, ymin, xmax, ymax )
# Out:
# 4.7920404 51.8573607 5.6273145 52.3036184

# %% [markdown]
# ## Lees data per plaats

# %%
postcodes = pd.read_excel('data/Consumenten_data/Postcodes Provincie Utrecht.xlsx') 
plaats = postcodes['Plaats'].unique()
postcodes.head()
# Out:
#    Postcode       Gemeente       Plaats  Aantal inwoners?
# 0      1390  De Ronde Venen     Abcoude               NaN
# 1      1391  De Ronde Venen     Abcoude               NaN
# 2      1393  Stichtse Vecht  Nigtevecht               NaN
# 3      1396  De Ronde Venen  Baambrugge               NaN
# 4      1426  De Ronde Venen     de Hoef               NaN

# %%
area = utrecht_boundary.geometry.to_crs({'proj':'cea'}).area[0]/10**6
print('De provincie Utrecht beslaat {:.4f} km^2.'.format(area))
# Out:
# De provincie Utrecht beslaat 1560.3236 km^2.

# %%
gemeente_boundaries = {}
# fig,ax = plt.subplots()
# utrecht_boundary.plot(ax=ax,color='b')
for gemeente in plaats:
    query= gemeente+",Utrecht, The Netherlands"
    gdf = ox.geocode_to_gdf( query)
    fig,ax = plt.subplots()
    utrecht_boundary.plot(ax=ax,color='b')
    gdf.plot(ax=ax,color='r',alpha=0.8)
    plt.show()
    gemeente_boundaries[gemeente] = gdf
    gdf = gdf['geometry'].to_crs({'proj':'cea'}) 
    print(gemeente+' area: {:.2f} square km'.format(gdf.area[0]/10**6))
# Out:
# Abcoude area: 22.74 square km
# Nigtevecht area: 4.58 square km
# Baambrugge area: 9.41 square km
# de Hoef area: 5.68 square km
# Amstelhoek area: 0.95 square km
# IJsselstein area: 21.68 square km
# Benschop area: 22.82 square km
# Lopik area: 79.00 square km
# Lopikerkapel area: 8.41 square km
# Jaarsveld area: 0.35 square km
# Polsbroek area: 11.71 square km
# Montfoort area: 25.29 square km
# Oudewater area: 19.96 square km
# Snelrewaard area: 9.72 square km
# Nieuwegein area: 25.65 square km
# Woerden area: 24.49 square km
# Vleuten area: 8.95 square km
# De Meern area: 9.04 square km
# Linschoten area: 12.92 square km
# Papekop area: 5.08 square km
# Hekendorp area: 5.34 square km
# Kamerik area: 28.68 square km
# Zegveld area: 16.01 square km
# Harmelen area: 23.77 square km
# Utrecht area: 75.03 square km
# Maarssen area: 16.12 square km
# Oud Zuilen area: 1.45 square km
# Tienhoven area: 13.36 square km
# Westbroek area: 12.38 square km
# Breukelen area: 21.47 square km
# Nieuwer Ter Aa area: 7.67 square km
# Kockengen area: 19.48 square km
# Nieuwersluis area: 6.78 square km
# Loenen aan de Vecht area: 8.64 square km
# Vreeland area: 5.15 square km
# Loenersloot area: 2.14 square km
# Mijdrecht area: 19.33 square km
# Vinkeveen area: 25.59 square km
# Waverveen area: 12.37 square km
# Wilnis area: 20.93 square km
# Zeist area: 28.76 square km
# Austerlitz area: 4.36 square km
# Huis ter Heide area: 4.47 square km
# Bilthoven area: 16.72 square km
# De Bilt area: 67.14 square km
# Den Dolder area: 6.51 square km
# Bosch en Duin area: 4.58 square km
# Groenekan area: 12.14 square km
# Maartensdijk area: 7.25 square km
# Hollandsche Rading area: 8.33 square km
# Baarn area: 27.86 square km
# Lage Vuursche area: 5.15 square km
# Bunschoten-Spakenburg area: 28.05 square km
# Eemdijk area: 6.77 square km
# Eemnes area: 33.71 square km
# Soest area: 40.83 square km
# Soesterberg area: 5.61 square km
# Achterveld area: 7.77 square km
# Amersfoort area: 44.77 square km
# Hoogland area: 14.79 square km
# Hooglanderveen area: 1.20 square km
# Leusden area: 47.49 square km
# Stoutenburg area: 3.65 square km
# Stoutenburg Noord area: 4.73 square km
# Veenendaal area: 19.73 square km
# Rhenen area: 33.63 square km
# Elst Ut area: 10.14 square km
# Renswoude area: 18.51 square km
# Woudenberg area: 36.81 square km
# Doorn area: 22.23 square km
# Cothen area: 11.93 square km
# Langbroek area: 17.90 square km
# Maarn area: 12.50 square km
# Maarsbergen area: 12.85 square km
# Leersum area: 29.85 square km
# Amerongen area: 18.87 square km
# Overberg area: 11.22 square km
# Wijk bij Duurstede area: 20.58 square km
# Driebergen-Rijsenburg area: 26.45 square km
# Bunnik area: 37.58 square km
# Odijk area: 8.00 square km
# Werkhoven area: 15.99 square km
# Ossenwaard area: 0.40 square km
# Houten area: 19.82 square km
# 't Goy area: 6.63 square km
# Schalkwijk area: 26.31 square km
# Tull en 't Waal area: 6.24 square km
# Everdingen area: 7.71 square km
# Zijderveld area: 4.95 square km
# Hagestein area: 8.06 square km
# Hoef en Haag area: 0.76 square km
# Hei- en Boeicop area: 8.67 square km
# Lexmond area: 22.91 square km
# Vianen area: 20.52 square km
# Leerdam area: 17.56 square km
# Schoonrewoerd area: 7.79 square km
# Oosterwijk area: 1.20 square km
# Meerkerk area: 15.22 square km
# Ameide area: 5.24 square km
# Tienhoven aan de Lek area: 4.35 square km
# Nieuwland area: 9.85 square km
# Leerbroek area: 10.26 square km
# Kedichem area: 7.88 square km

# %%
import os
import time
import glob

cwd = os.getcwd()
caches = ['/data/cache/footprints_building/Utrecht_{}.pickle','/data/cache/footprints_landuse/Utrecht_{}.pickle','/data/cache/graph_raw/Utrecht.pickle']
# nx.write_gpickle(G,cwd+caches[2])
buildings = pd.DataFrame()
footpr = pd.DataFrame()
for gemeente in plaats:
    print(gemeente)
    pickleFilenamesList = glob.glob(cwd+caches[0].format(gemeente+'*'))
    st = time.time()
    for file in pickleFilenamesList:
        buildings=buildings.append(pd.read_pickle(file))
    print('for {} it took {:.2f} seconds to read buildings'.format(gemeente,time.time()-st))
    
    pickleFilenamesList = glob.glob(cwd+caches[1].format(gemeente+'*'))
    st = time.time()
    for file in pickleFilenamesList:
        footpr=footpr.append(pd.read_pickle(file))
    print('for {} it took {:.2f} seconds to read landuse'.format(gemeente,time.time()-st))
# Out:
# Abcoude
# for Abcoude it took 0.04 seconds to read buildings
# for Abcoude it took 0.01 seconds to read landuse
# Nigtevecht
# for Nigtevecht it took 0.02 seconds to read buildings
# for Nigtevecht it took 0.01 seconds to read landuse
# Baambrugge
# for Baambrugge it took 0.02 seconds to read buildings
# for Baambrugge it took 0.02 seconds to read landuse
# de Hoef
# for de Hoef it took 0.02 seconds to read buildings
# for de Hoef it took 0.01 seconds to read landuse
# Amstelhoek
# for Amstelhoek it took 0.02 seconds to read buildings
# for Amstelhoek it took 0.02 seconds to read landuse
# IJsselstein
# for IJsselstein it took 0.10 seconds to read buildings
# for IJsselstein it took 0.02 seconds to read landuse
# Benschop
# for Benschop it took 0.04 seconds to read buildings
# for Benschop it took 0.14 seconds to read landuse
# Lopik
# for Lopik it took 0.13 seconds to read buildings
# for Lopik it took 0.05 seconds to read landuse
# Lopikerkapel
# for Lopikerkapel it took 0.06 seconds to read buildings
# for Lopikerkapel it took 0.02 seconds to read landuse
# Jaarsveld
# for Jaarsveld it took 0.05 seconds to read buildings
# for Jaarsveld it took 0.02 seconds to read landuse
# Polsbroek
# for Polsbroek it took 0.05 seconds to read buildings
# for Polsbroek it took 0.02 seconds to read landuse
# Montfoort
# for Montfoort it took 0.07 seconds to read buildings
# for Montfoort it took 0.02 seconds to read landuse
# Oudewater
# for Oudewater it took 0.07 seconds to read buildings
# for Oudewater it took 0.02 seconds to read landuse
# Snelrewaard
# for Snelrewaard it took 0.05 seconds to read buildings
# for Snelrewaard it took 0.02 seconds to read landuse
# Nieuwegein
# for Nieuwegein it took 0.28 seconds to read buildings
# for Nieuwegein it took 0.02 seconds to read landuse
# Woerden
# for Woerden it took 0.21 seconds to read buildings
# for Woerden it took 0.02 seconds to read landuse
# Vleuten
# for Vleuten it took 0.19 seconds to read buildings
# for Vleuten it took 0.02 seconds to read landuse
# De Meern
# for De Meern it took 0.21 seconds to read buildings
# for De Meern it took 0.02 seconds to read landuse
# Linschoten
# for Linschoten it took 0.17 seconds to read buildings
# for Linschoten it took 0.02 seconds to read landuse
# Papekop
# for Papekop it took 0.14 seconds to read buildings
# for Papekop it took 0.02 seconds to read landuse
# Hekendorp
# for Hekendorp it took 0.14 seconds to read buildings
# for Hekendorp it took 0.03 seconds to read landuse
# Kamerik
# for Kamerik it took 0.15 seconds to read buildings
# for Kamerik it took 0.03 seconds to read landuse
# Zegveld
# for Zegveld it took 0.15 seconds to read buildings
# for Zegveld it took 0.03 seconds to read landuse
# Harmelen
# for Harmelen it took 0.20 seconds to read buildings
# for Harmelen it took 0.03 seconds to read landuse
# Utrecht
# for Utrecht it took 2.37 seconds to read buildings
# for Utrecht it took 0.11 seconds to read landuse
# Maarssen
# for Maarssen it took 0.69 seconds to read buildings
# for Maarssen it took 0.03 seconds to read landuse
# Oud Zuilen
# for Oud Zuilen it took 0.56 seconds to read buildings
# for Oud Zuilen it took 0.02 seconds to read landuse
# Tienhoven
# for Tienhoven it took 1.19 seconds to read buildings
# for Tienhoven it took 0.07 seconds to read landuse
# Westbroek
# for Westbroek it took 0.51 seconds to read buildings
# for Westbroek it took 0.02 seconds to read landuse
# Breukelen
# for Breukelen it took 0.73 seconds to read buildings
# for Breukelen it took 0.03 seconds to read landuse
# Nieuwer Ter Aa
# for Nieuwer Ter Aa it took 0.62 seconds to read buildings
# for Nieuwer Ter Aa it took 0.03 seconds to read landuse
# Kockengen
# for Kockengen it took 0.54 seconds to read buildings
# for Kockengen it took 0.04 seconds to read landuse
# Nieuwersluis
# for Nieuwersluis it took 0.56 seconds to read buildings
# for Nieuwersluis it took 0.03 seconds to read landuse
# Loenen aan de Vecht
# for Loenen aan de Vecht it took 0.57 seconds to read buildings
# for Loenen aan de Vecht it took 0.03 seconds to read landuse
# Vreeland
# for Vreeland it took 0.65 seconds to read buildings
# for Vreeland it took 0.03 seconds to read landuse
# Loenersloot
# for Loenersloot it took 0.55 seconds to read buildings
# for Loenersloot it took 0.03 seconds to read landuse
# Mijdrecht
# for Mijdrecht it took 0.73 seconds to read buildings
# for Mijdrecht it took 0.03 seconds to read landuse
# Vinkeveen
# for Vinkeveen it took 1.32 seconds to read buildings
# for Vinkeveen it took 0.07 seconds to read landuse
# Waverveen
# for Waverveen it took 0.61 seconds to read buildings
# for Waverveen it took 0.05 seconds to read landuse
# Wilnis
# for Wilnis it took 1.02 seconds to read buildings
# for Wilnis it took 0.04 seconds to read landuse
# Zeist
# for Zeist it took 2.53 seconds to read buildings
# for Zeist it took 0.10 seconds to read landuse
# Austerlitz
# for Austerlitz it took 0.74 seconds to read buildings
# for Austerlitz it took 0.05 seconds to read landuse
# Huis ter Heide
# for Huis ter Heide it took 1.05 seconds to read buildings
# for Huis ter Heide it took 0.03 seconds to read landuse
# Bilthoven
# for Bilthoven it took 0.98 seconds to read buildings
# for Bilthoven it took 0.03 seconds to read landuse
# De Bilt
# for De Bilt it took 3.88 seconds to read buildings
# for De Bilt it took 0.13 seconds to read landuse
# Den Dolder
# for Den Dolder it took 0.94 seconds to read buildings
# for Den Dolder it took 0.03 seconds to read landuse
# Bosch en Duin
# for Bosch en Duin it took 1.03 seconds to read buildings
# for Bosch en Duin it took 0.04 seconds to read landuse
# Groenekan
# for Groenekan it took 0.89 seconds to read buildings
# for Groenekan it took 0.03 seconds to read landuse
# Maartensdijk
# for Maartensdijk it took 1.01 seconds to read buildings
# for Maartensdijk it took 0.03 seconds to read landuse
# Hollandsche Rading
# for Hollandsche Rading it took 0.89 seconds to read buildings
# for Hollandsche Rading it took 0.04 seconds to read landuse
# Baarn
# for Baarn it took 2.01 seconds to read buildings
# for Baarn it took 0.06 seconds to read landuse
# Lage Vuursche
# for Lage Vuursche it took 0.93 seconds to read buildings
# for Lage Vuursche it took 0.03 seconds to read landuse
# Bunschoten-Spakenburg
# for Bunschoten-Spakenburg it took 1.99 seconds to read buildings
# for Bunschoten-Spakenburg it took 0.07 seconds to read landuse
# Eemdijk
# for Eemdijk it took 0.93 seconds to read buildings
# for Eemdijk it took 0.03 seconds to read landuse
# Eemnes
# for Eemnes it took 1.87 seconds to read buildings
# for Eemnes it took 0.06 seconds to read landuse
# Soest
# for Soest it took 3.25 seconds to read buildings
# for Soest it took 0.10 seconds to read landuse
# Soesterberg
# for Soesterberg it took 1.04 seconds to read buildings
# for Soesterberg it took 0.04 seconds to read landuse
# Achterveld
# for Achterveld it took 1.06 seconds to read buildings
# for Achterveld it took 0.03 seconds to read landuse
# Amersfoort
# for Amersfoort it took 3.64 seconds to read buildings
# for Amersfoort it took 0.06 seconds to read landuse
# Hoogland
# for Hoogland it took 2.67 seconds to read buildings
# for Hoogland it took 0.07 seconds to read landuse
# Hooglanderveen
# for Hooglanderveen it took 1.42 seconds to read buildings
# for Hooglanderveen it took 0.04 seconds to read landuse
# Leusden
# for Leusden it took 2.92 seconds to read buildings
# for Leusden it took 0.08 seconds to read landuse
# Stoutenburg
# for Stoutenburg it took 2.72 seconds to read buildings
# for Stoutenburg it took 0.07 seconds to read landuse
# Stoutenburg Noord
# for Stoutenburg Noord it took 1.42 seconds to read buildings
# for Stoutenburg Noord it took 0.04 seconds to read landuse
# Veenendaal
# for Veenendaal it took 2.24 seconds to read buildings
# for Veenendaal it took 0.05 seconds to read landuse
# Rhenen
# for Rhenen it took 3.94 seconds to read buildings
# for Rhenen it took 0.08 seconds to read landuse
# Elst Ut
# for Elst Ut it took 1.42 seconds to read buildings
# for Elst Ut it took 0.03 seconds to read landuse
# Renswoude
# for Renswoude it took 1.43 seconds to read buildings
# for Renswoude it took 0.04 seconds to read landuse
# Woudenberg
# for Woudenberg it took 3.25 seconds to read buildings
# for Woudenberg it took 0.09 seconds to read landuse
# Doorn
# for Doorn it took 1.92 seconds to read buildings
# for Doorn it took 0.03 seconds to read landuse
# Cothen
# for Cothen it took 2.06 seconds to read buildings
# for Cothen it took 0.04 seconds to read landuse
# Langbroek
# for Langbroek it took 1.80 seconds to read buildings
# for Langbroek it took 0.05 seconds to read landuse
# Maarn
# for Maarn it took 1.98 seconds to read buildings
# for Maarn it took 0.04 seconds to read landuse
# Maarsbergen
# for Maarsbergen it took 1.82 seconds to read buildings
# for Maarsbergen it took 0.04 seconds to read landuse
# Leersum
# for Leersum it took 3.76 seconds to read buildings
# for Leersum it took 0.08 seconds to read landuse
# Amerongen
# for Amerongen it took 2.03 seconds to read buildings
# for Amerongen it took 0.04 seconds to read landuse
# Overberg
# for Overberg it took 1.83 seconds to read buildings
# for Overberg it took 0.04 seconds to read landuse
# Wijk bij Duurstede
# for Wijk bij Duurstede it took 2.50 seconds to read buildings
# for Wijk bij Duurstede it took 0.05 seconds to read landuse
# Driebergen-Rijsenburg
# for Driebergen-Rijsenburg it took 4.44 seconds to read buildings
# for Driebergen-Rijsenburg it took 0.08 seconds to read landuse
# Bunnik
# for Bunnik it took 4.84 seconds to read buildings
# for Bunnik it took 0.09 seconds to read landuse
# Odijk
# for Odijk it took 2.25 seconds to read buildings
# for Odijk it took 0.05 seconds to read landuse
# Werkhoven
# for Werkhoven it took 2.00 seconds to read buildings
# for Werkhoven it took 0.04 seconds to read landuse
# Ossenwaard
# for Ossenwaard it took 1.71 seconds to read buildings
# for Ossenwaard it took 0.03 seconds to read landuse
# Houten
# for Houten it took 2.49 seconds to read buildings
# for Houten it took 0.05 seconds to read landuse
# 't Goy
# for 't Goy it took 1.81 seconds to read buildings
# for 't Goy it took 0.04 seconds to read landuse
# Schalkwijk
# for Schalkwijk it took 4.24 seconds to read buildings
# for Schalkwijk it took 0.09 seconds to read landuse
# Tull en 't Waal
# for Tull en 't Waal it took 2.18 seconds to read buildings
# for Tull en 't Waal it took 0.04 seconds to read landuse
# Everdingen
# for Everdingen it took 2.40 seconds to read buildings
# for Everdingen it took 0.05 seconds to read landuse
# Zijderveld
# for Zijderveld it took 1.92 seconds to read buildings
# for Zijderveld it took 0.05 seconds to read landuse
# Hagestein
# for Hagestein it took 2.02 seconds to read buildings
# for Hagestein it took 0.04 seconds to read landuse
# Hoef en Haag
# for Hoef en Haag it took 2.02 seconds to read buildings
# for Hoef en Haag it took 0.04 seconds to read landuse
# Hei- en Boeicop
# for Hei- en Boeicop it took 2.02 seconds to read buildings
# for Hei- en Boeicop it took 0.04 seconds to read landuse
# Lexmond
# for Lexmond it took 2.46 seconds to read buildings
# for Lexmond it took 0.07 seconds to read landuse
# Vianen
# for Vianen it took 2.71 seconds to read buildings
# for Vianen it took 0.06 seconds to read landuse
# Leerdam
# for Leerdam it took 2.47 seconds to read buildings
# for Leerdam it took 0.05 seconds to read landuse
# Schoonrewoerd
# for Schoonrewoerd it took 2.08 seconds to read buildings
# for Schoonrewoerd it took 0.05 seconds to read landuse
# Oosterwijk
# for Oosterwijk it took 2.14 seconds to read buildings
# for Oosterwijk it took 0.04 seconds to read landuse
# Meerkerk
# for Meerkerk it took 2.36 seconds to read buildings
# for Meerkerk it took 0.05 seconds to read landuse
# Ameide
# for Ameide it took 2.36 seconds to read buildings
# for Ameide it took 0.05 seconds to read landuse
# Tienhoven aan de Lek
# for Tienhoven aan de Lek it took 2.17 seconds to read buildings
# for Tienhoven aan de Lek it took 0.05 seconds to read landuse
# Nieuwland
# for Nieuwland it took 2.25 seconds to read buildings
# for Nieuwland it took 0.05 seconds to read landuse
# Leerbroek
# for Leerbroek it took 2.44 seconds to read buildings
# for Leerbroek it took 0.05 seconds to read landuse
# Kedichem
# for Kedichem it took 2.10 seconds to read buildings
# for Kedichem it took 0.05 seconds to read landuse

# %%
vcount = list(footpr.landuse.value_counts()[:25].index)
colors = {'village_green':'lightgreen','static_caravan':'yellow','water':'aqua',
            'road':'lightblue','mobile_home':'gray','building':'saddlebrown',
            'grass':'g','forest':'forestgreen','meadow':'lightgreen',
            'park':'palegreen','recreation_ground':'gold','commercial':'pink',
            'residential':'khaki','railway':'gray','retail':'fuchsia',
            'orchard':'darkgreen','allotments':'lightgray','industrial':'darkgray',
            'cemetery':'dimgray','farmland':'wheat','farmyard':'goldenrod',
            'paved':'rosybrown','construction':'indianred','reservoir':'lightblue',
            'depot':'gray','traffic_island':'brown','religious':'tan',
            'basin':'aqua','corral':'brown','greenhouse':'white','greenhouse_horticulture':'white'}

colormap = {}
for landuse in vcount:
    if landuse not in colors.keys():
        colormap[landuse] = 'indigo'
    else:
        colormap[landuse] = colors[landuse]

# %%
def plot_map(footpr,water,building,nodes,edges,vcount,xmin=xmin,xmax=xmax,ymin=ymin,ymax=ymax):
    fig,ax=plt.subplots(figsize=(12,12))
    if len(footpr)>0:
        for i in range(0,len(vcount)):
            sub_footpr = footpr[footpr.landuse==vcount[i]]
            sub_footpr.plot(ax=ax,facecolor=colormap[vcount[i]], alpha=0.7,label=vcount[i])


    if len(water)>0:
        water[water.natural=='water'].plot(ax=ax,edgecolor='aqua',facecolor='aqua', alpha=0.5)
    if len(building)>0:
        building.plot(ax=ax,facecolor='saddlebrown',alpha=1)

    ax.set_xlim(xmin,xmax)
    ax.set_ylim(ymin,ymax)
    markers = [plt.Line2D([0,0],[0,0],color=color, marker='o', linestyle='') for color in colormap.values()]
    plt.legend(markers, colormap.keys(), loc=(1.04,0),numpoints=1)
    plt.show()
    

    
plot_map(footpr,[],buildings,[],[],vcount)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-43659762a201> in <module>
#      20
#      21
# ---> 22 plot_map(footpr,[],buildings,[],[],vcount)
#      23
#
# <ipython-input-61-43659762a201> in plot_map(footpr, water, building, nodes, edges, vcount, xmin, xmax, ymin, ymax)
#      10         water[water.natural=='water'].plot(ax=ax,edgecolor='aqua',facecolor='aqua', alpha=0.5)
#      11     if len(building)>0:
# ---> 12         building.plot(ax=ax,facecolor='saddlebrown',alpha=1)
#      13
#      14     ax.set_xlim(xmin,xmax)
#
# ~/opt/anaconda3/envs/ox/lib/python3.9/site-packages/geopandas/plotting.py in __call__(self, *args, **kwargs)
#     923             kind = kwargs.pop("kind", "geo")
#     924             if kind == "geo":
# --> 925                 return plot_dataframe(data, *args, **kwargs)
#     926             if kind in self._pandas_kinds:
#     927                 # Access pandas plots
#
# ~/opt/anaconda3/envs/ox/lib/python3.9/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     687
#     688     if column is None:
# --> 689         return plot_series(
#     690             df.geometry,
#     691             cmap=cmap,
#
# ~/opt/anaconda3/envs/ox/lib/python3.9/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     445
#     446         values_ = values[poly_idx] if cmap else None
# --> 447         _plot_polygon_collection(
#     448             ax, polys, values_, facecolor=facecolor, cmap=cmap, **style_kwds
#     449         )
#
# ~/opt/anaconda3/envs/ox/lib/python3.9/site-packages/geopandas/plotting.py in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     170
#     171     collection = PatchCollection(
# --> 172         [_PolygonPatch(poly) for poly in geoms if not poly.is_empty], **kwargs
#     173     )
#     174
#
# ~/opt/anaconda3/envs/ox/lib/python3.9/site-packages/geopandas/plotting.py in <listcomp>(.0)
#     170
#     171     collection = PatchCollection(
# --> 172         [_PolygonPatch(poly) for poly in geoms if not poly.is_empty], **kwargs
#     173     )
#     174
#
# ~/opt/anaconda3/envs/ox/lib/python3.9/site-packages/geopandas/plotting.py in _PolygonPatch(polygon, **kwargs)
#     114     from matplotlib.path import Path
#     115
# --> 116     path = Path.make_compound_path(
#     117         Path(np.asarray(polygon.exterior.coords)[:, :2]),
#     118         *[Path(np.asarray(ring.coords)[:, :2]) for ring in polygon.interiors],
#
# ~/opt/anaconda3/envs/ox/lib/python3.9/site-packages/matplotlib/path.py in make_compound_path(cls, *args)
#     341         codes = codes[not_stop_mask]
#     342
# --> 343         return cls(vertices, codes)
#     344
#     345     def __repr__(self):
#
# ~/opt/anaconda3/envs/ox/lib/python3.9/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#      96                              CLOSEPOLY: 1}
#      97
# ---> 98     def __init__(self, vertices, codes=None, _interpolation_steps=1,
#      99                  closed=False, readonly=False):
#     100         """
#
# KeyboardInterrupt:

# %%
folder = 'data/Producenten_data/'
file = 'Landbouw__hoofdbedrijfstype__regio_10062021_144933.csv'
import geopandas as gpd

prod = pd.read_csv(folder+file,sep=';')

# %%
prod['Grondgebruik/Oppervlakte/Grondgebruik, totaal (are)']/prod['Grondgebruik/Oppervlakte/Grondgebruik, totaal (are)'].iloc[0]*100

# %%
prod

# %%
file = 'Landbouw__vanaf_1851_16062021_102354.csv'
prod = pd.read_csv(folder+file,sep=',')
prod = prod.dropna()
prod[['Onderwerp','x','2020']] = prod[prod.columns[0]].str.split(';',expand=True)
prod = prod.drop(prod.columns[0],axis=1)
prod = prod.drop([1,2],axis=0)

# %%
prod['2020'] = pd.to_numeric(prod['2020'].str.strip('""'),errors='coerce')

# %%
prod
